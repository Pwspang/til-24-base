# %%
import jsonlines
import torchaudio
from datasets import Dataset
from transformers.pipelines.pt_utils import KeyDataset
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline, GenerationConfig
from pathlib import Path
import torch
import librosa
import IPython.display as ipd

# %%
def get_suppressed_tokens(tokenizer):
    # if keep_numbers_string:
    #     number_tokens = [i for i in range(whisper_processor.tokenizer.vocab_size) if all(c in "0123456789$£&\"\'" for c in whisper_processor.tokenizer.decode([i]).removeprefix(" "))]
    tokens_file_path = Path("./cache_tokens")
    bad_tokens_str = [r"0",
                      r"1",
                      r"2",
                      r"3",
                      r"4",
                      r"5",
                      r"6",
                      r"7",
                      r"8",
                      r"9",
                      "$",
                      "£", ]
                      # "&",
                      # "\"",
                      # r"...",
                      # "..",
                      # "#",
                      # "№",
                      # "@",
                      # "*",
                      # "--"]
    # if tokens_file_path.exists():
    #     pass
    #     #tokens_dict = deserialize_data(tokens_file_path)
    # else:
    tokens_dict = dict()

    all_tokens_cached = True

    for token_num in range(tokenizer.vocab_size):
        token_str = tokenizer.decode([token_num]).removeprefix(" ")
        for bad_token in bad_tokens_str:
            if bad_token not in tokens_dict:
                tokens_dict[bad_token] = [False, [], []]
                all_tokens_cached = False

            if not tokens_dict[bad_token][0]:
                if bad_token in token_str:
                    tokens_dict[bad_token][1].append(token_num)
                    tokens_dict[bad_token][2].append(token_str)
        if all_tokens_cached:
            break

    result = []
    for k, v in tokens_dict.items():
        tokens_dict[k][0] = True
        if k in bad_tokens_str:
            result += v[1]
    #serialize_data(tokens_dict, tokens_file_path)
    return list(set(result))

# %%
model_id = "openai/whisper-medium.en"

device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

model = AutoModelForSpeechSeq2Seq.from_pretrained(
    model_id, torch_dtype=torch_dtype, use_safetensors=True
)

processor = AutoProcessor.from_pretrained(model_id)
 
    
generation_config = GenerationConfig.from_pretrained(model_id)
generation_config.suppress_tokens += get_suppressed_tokens(processor.tokenizer)
generation_config.suppress_tokens = list(set(generation_config.suppress_tokens))
generation_config.suppress_tokens.sort()

pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    max_new_tokens=128,
    chunk_length_s=30,
    batch_size=16,
    return_timestamps=True,
    torch_dtype=torch_dtype,
    device=device,
)

audio_file = '/home/jupyter/advanced/audio/audio_1670.wav'
audio_input, sample_rate = librosa.load(audio_file, sr=16000)

transcription = pipe(audio_file, generate_kwargs={"generation_config": generation_config})

print("Transcription:", transcription['text'])
# Out:
# Transcription:  Control here, surface to air missile heading zero six zero, engage the silver and orange camouflage helicopter. That's zero six zero, over.

# %%
audio_data, sampling_rate = librosa.load(audio_file, sr=None)
waveform, sample_rate = torchaudio.load(audio_file)
ipd.Audio(waveform, rate=sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Define the path to the directory
data_dir = Path("/home/jupyter/advanced")

# Read data from a jsonl file and reformat it
data = {'key': [], 'audio': [], 'transcript': []}
with jsonlines.open(data_dir / "asr.jsonl") as reader:
    for obj in reader:
        for key, value in obj.items():
            if key == 'audio':
                data[key].append("/home/jupyter/advanced/audio/" + value)
            else:
                data[key].append(value)

# Convert to a Hugging Face dataset
dataset = Dataset.from_dict(data)

# Shuffle the dataset
dataset = dataset.shuffle(seed=42)

# Split the dataset into training, validation, and test sets
train_size = int(0.8 * len(dataset))
val_size = int(0.05 * len(dataset))
test_size = len(dataset) - train_size - val_size

train_dataset = dataset.select(range(train_size))
val_dataset = dataset.select(range(train_size, train_size + val_size))
test_dataset = dataset.select(range(train_size + val_size, train_size + val_size + test_size))

# %%
#val_dataset['audio']

# %% [markdown]
# # Model Evaluation

# %%
import jiwer

# Function to calculate WER
def calculate_wer(references, hypotheses):
    wer_scores = []
    for ref, hyp in zip(references, hypotheses):
        wer_score = jiwer.wer(ref, hyp)
        wer_scores.append(wer_score)
    return wer_scores

# Calculate WER for each pair

# %%
references = val_dataset['transcript']
hypothesis = []

for out in pipe(KeyDataset(val_dataset, 'audio'), generate_kwargs={"generation_config": generation_config}):
    hypothesis.append(out['text'])

print(len(references))
print(len(hypothesis))

wer_scores = calculate_wer(references, hypothesis)
# Out:
# 175
# 175

# %%
wer_scores = calculate_wer(references, hypothesis)
data = pd.DataFrame(dict(hypothesis=hypothesis, reference=references))
data
# Out:
#                                                                                                                                                                                                      hypothesis  \
# 0                                                    Torret Romeo heading two six five engage brown camouflage fighter plane with anti-air artillery target confirmed strike with precision stand by for impact
# 1                                                                                                      Control tower to air defense turret. Target is a white drone heading one eight zero. Deploy machine gun.
# 2                                                                     Turret Bravo, deploy EMP on the Silver, Blue and Purple commercial aircraft heading two-niner-zero. Target locked, awaiting confirmation.
# 3                                          Control to Air Defence Turrets, deploy EMP towards the green, white and silver missile at heading zero six five. Engage and neutralise the target immediately. Over.
# 4                                    Turret Alpha, deploy surface-to-air missiles at heading one five five. Target the orange, brown and black fighter plane. Defensive measures initiated. Standby for impact.
# ..                                                                                                                                                                                                          ...
# 170                                                   Control tower to Taurus. Prepare to deploy electromagnetic pulse. Target is a red commercial aircraft on heading one three five. Take action immediately.
# 171                                                                                                                         Engage target, white and orange helicopter heading one-niner-five with machine gun.
# 172   Control to air defense turrets. Focus your attention to heading two two five. Prepare to deploy EMP tool against the brown and white commercial aircraft. Engage and neutralize the target swiftly. Over.
# 173                                                                                           Control here. Prepare to engage Brown Fighter Jet at heading two-four-five using machine gun. Fire at will. Over.
# 174                                                                                                           Tango deploy electromagnetic pulse at heading one four zero targeting blue and green fighter jet.
#
#                                                                                                                                                                                                      reference
# 0                                             Turret Romeo, heading two six five, engage brown camouflage fighter plane with anti-air artillery. Target confirmed. Strike with precision. Stand by for impact.
# 1                                                                                                    Control tower to air defense turrets, target is a white drone heading one eight zero, deploy machine gun.
# 2                                                                   Turret Bravo, deploy EMP on the silver, blue, and purple commercial aircraft heading two niner zero. Target locked, awaiting confirmation.
# 3                                        Control to air defense turrets, deploy EMP towards the green, white, and silver missile at heading zero six five. Engage and neutralize the target immediately. Over.
# 4                                  Turret Alpha, deploy surface-to-air missiles at heading one five five. Target the orange, brown, and black fighter plane. Defensive measures initiated. Standby for impact.
# ..                                                                                                                                                                                                         ...
# 170                                                 Control tower to turrets, prepare to deploy electromagnetic pulse. Target is a red commercial aircraft on heading one three five. Take action immediately.
# 171                                                                                                                      Engage target, white and orange helicopter, heading one niner five, with machine gun.
# 172  Control to air defense turrets, focus your attention to heading two two five. Prepare to deploy EMP tool against the brown and white commercial aircraft. Engage and neutralize the target swiftly. Over.
# 173                                                                                          Control here. Prepare to engage brown fighter jet at heading two four five using machine gun. Fire at will. Over.
# 174                                                                                                        Tango, deploy electromagnetic pulse at heading one four zero, targeting blue and green fighter jet.
#
# [175 rows x 2 columns]

# %%
wer = jiwer.wer(list(data["hypothesis"]), list(data["reference"]))

print(f"WER: {wer * 100:.2f} %")

# Display the results
for i, score in enumerate(wer_scores):
    print(f"Reference {i+1}: {references[i]}")
    print(f"Hypothesis {i+1}: {hypothesis[i]}")
    print(f"WER: {score:.2%}\n")
# Out:
# WER: 21.08 %
# Reference 1: Turret Romeo, heading two six five, engage brown camouflage fighter plane with anti-air artillery. Target confirmed. Strike with precision. Stand by for impact.
# Hypothesis 1:  Torret Romeo heading two six five engage brown camouflage fighter plane with anti-air artillery target confirmed strike with precision stand by for impact
# WER: 43.48%
#
# Reference 2: Control tower to air defense turrets, target is a white drone heading one eight zero, deploy machine gun.
# Hypothesis 2:  Control tower to air defense turret. Target is a white drone heading one eight zero. Deploy machine gun.
# WER: 22.22%
#
# Reference 3: Turret Bravo, deploy EMP on the silver, blue, and purple commercial aircraft heading two niner zero. Target locked, awaiting confirmation.
# Hypothesis 3:  Turret Bravo, deploy EMP on the Silver, Blue and Purple commercial aircraft heading two-niner-zero. Target locked, awaiting confirmation.
# WER: 30.00%
#
# Reference 4: Control to air defense turrets, deploy EMP towards the green, white, and silver missile at heading zero six five. Engage and neutralize the target immediately. Over.
# Hypothesis 4:  Control to Air Defence Turrets, deploy EMP towards the green, white and silver missile at heading zero six five. Engage and neutralise the target immediately. Over.
# WER: 19.23%
#
# Reference 5: Turret Alpha, deploy surface-to-air missiles at heading one five five. Target the orange, brown, and black fighter plane. Defensive measures initiated. Standby for impact.
# Hypothesis 5:  Turret Alpha, deploy surface-to-air missiles at heading one five five. Target the orange, brown and black fighter plane. Defensive measures initiated. Standby for impact.
# WER: 4.17%
#
# Reference 6: Control here, prepare to engage the purple helicopter at heading zero eight zero utilizing EMP. Commence deployment immediately.
# Hypothesis 6:  Control here. Prepare to engage the purple helicopter at heading zero eight zero, utilizing EMP. Commence deployment immediately.
# WER: 16.67%
#
# Reference 7: Engage, surface-to-air missiles, heading zero seven five. Target is a green, brown, and white cargo aircraft. Take the shot.
# Hypothesis 7:  Engage. Surface to air missiles heading zero seven five. Target is a green, brown and white cargo aircraft. Take the shot.
# WER: 31.58%
#
# Reference 8: Deploy EMP, heading two niner zero, engage black helicopter.
# Hypothesis 8:  Deploy EMP Heading two-niner-zero, engage black helicopter.
# WER: 55.56%
#
# Reference 9: Control tower to interceptor jets, track and intercept orange and silver cargo aircraft heading two niner five.
# Hypothesis 9:  Control tower to interceptor jets, track and intercept orange and silver cargo aircraft heading two-niner-five
# WER: 17.65%
#
# Reference 10: Engage target, red, green, and blue fighter jet, with anti-air artillery. Heading two three zero. Protect the airspace.
# Hypothesis 10:  Engage target red, green and blue fighter jet with anti-air artillery. Heading two-three-zero. Protect the airspace.
# WER: 33.33%
#
# Reference 11: Control here. Deploy electromagnetic pulse against the purple, orange, and white drone at heading zero seven five. Over.
# Hypothesis 11:  Control here. Deploy electromagnetic pulse against the purple, orange and white drone at heading zero seven five. Over.
# WER: 5.56%
#
# Reference 12: Control to all air defense turrets, we have an orange and blue cargo aircraft on heading zero one zero. Deploy surface-to-air missiles immediately. Repeat, deploy surface-to-air missiles.
# Hypothesis 12:  Control to all air defense turrets. We have an orange and blue cargo aircraft on heading zero one zero deploy surface to air missiles immediately. Repeat deploy surface to air missiles.
# WER: 40.74%
#
# Reference 13: Initiate interception protocol, deploy interceptor jets to heading zero one zero, engage black fighter plane.
# Hypothesis 13:  Initiate interception protocol. Deploy interceptor jets to heading zero one zero. Engage Black Fighter plane.
# WER: 40.00%
#
# Reference 14: Tango turrets, deploy anti-air artillery, heading one zero zero, engage black and blue commercial aircraft.
# Hypothesis 14:  Tango turrets, deploy anti-air artillery heading one zero zero. Engage black and blue commercial aircraft.
# WER: 20.00%
#
# Reference 15: Turret Alpha, deploy electromagnetic pulse on orange and silver fighter plane heading two two zero.
# Hypothesis 15:  Turret Alpha deploy electromagnetic pulse on orange and silver fighter plane heading two two zero.
# WER: 6.67%
#
# Reference 16: Engage target, black and purple fighter jet, heading three zero five. Deploy anti-air artillery.
# Hypothesis 16:  Engage target. Black and purple fighter jets heading three zero five. Deploy anti-air artillery.
# WER: 21.43%
#
# Reference 17: Engage interceptor jets to intercept the yellow and black commercial aircraft heading one niner five.
# Hypothesis 17:  Engage interceptor jets to intercept the yellow and black commercial aircraft heading one-niner-five.
# WER: 20.00%
#
# Reference 18: Control here, target at heading two eight five, deploy electromagnetic pulse against the blue, green, and white missile. Over.
# Hypothesis 18:  Control here. Target at heading two eight five. Deploy electromagnetic pulse against the blue, green and white missile. Over.
# WER: 26.32%
#
# Reference 19: Control to air defense turrets, surface-to-air missiles authorized for deployment. Heading one zero five, target is a black light aircraft. Engage at will.
# Hypothesis 19:  Control to air defense turret surface to air missiles authorized for deployment Heading one zero five target is a black light aircraft engage at will
# WER: 39.13%
#
# Reference 20: Control here. Deploy the EMP tool heading two zero zero to engage the silver and black commercial aircraft. Over.
# Hypothesis 20:  Control here. Deploy the EMP-II heading two zero zero to engage the silver and black commercial aircraft. Over.
# WER: 10.53%
#
# Reference 21: Turrets, deploy anti-air artillery, heading zero three zero, engage red, yellow, and black light aircraft.
# Hypothesis 21:  Turrets deploy anti-air artillery heading zero three zero, engage red, yellow and black light aircraft.
# WER: 20.00%
#
# Reference 22: Control tower to air defense turrets, target is a black commercial aircraft heading one zero five. Deploy surface-to-air missiles. Engage target immediately.
# Hypothesis 22:  Control tower to Air Defense turrets. Target is a black commercial aircraft heading one zero five. Deploy surface to air missiles. Engage target immediately.
# WER: 31.82%
#
# Reference 23: Control tower to air defense turrets, engage target, brown fighter jet, heading three three zero, deploy machine gun.
# Hypothesis 23:  Control power to air defense turrets. Engage target. Ground fighter jets heading three three zero. Deploy machine gun.
# WER: 44.44%
#
# Reference 24: Turret Foxtrot, target the grey and silver drone at heading one six zero, deploy EMP.
# Hypothesis 24:  Turret Foxtrot, target the grey and silver drone at heading one six zero, deploy EMP.
# WER: 0.00%
#
# Reference 25: Control to air defense turrets, we have a white light aircraft at heading three four five. Deploy surface-to-air missiles immediately. Over.
# Hypothesis 25:  Control to air defense turret, we have a white light aircraft at heading three four five. Deploy surface to air missiles immediately. Over.
# WER: 19.05%
#
# Reference 26: Alpha, India, this is control tower. Deploy EMP on purple and blue helicopter heading three five zero. Engage target immediately.
# Hypothesis 26:  Alpha, India, this is control tower. Deploy EMP on purple and blue helicopter, heading three five zero. Engage target immediately.
# WER: 5.00%
#
# Reference 27: Fire electromagnetic pulse at heading two six zero to intercept blue light aircraft.
# Hypothesis 27:  fire electromagnetic pulse at heading two six zero to intercept blue light aircraft.
# WER: 7.69%
#
# Reference 28: Deploy machine gun, engage red, green, and purple fighter jet, heading one three five.
# Hypothesis 28:  Deploying machine gun engage red, green and purple fighter jet heading one three five.
# WER: 28.57%
#
# Reference 29: Control tower to turrets, deploy electromagnetic pulse on brown, yellow, and orange commercial aircraft at heading one niner zero.
# Hypothesis 29:  Control tower to turret, deploy electromagnetic pulse on brown, yellow and orange commercial aircraft at heading one-niner-zero.
# WER: 26.32%
#
# Reference 30: Rotate heading to one two zero, engage target, brown, orange, and white missile, with machine gun.
# Hypothesis 30:  Rotate heading to one two zero engage target brown orange and white missile with machine gun.
# WER: 31.25%
#
# Reference 31: Turret Alpha, heading three five zero, deploy EMP on the black, silver, and brown fighter jet.
# Hypothesis 31:  Turret Alpha, heading three five zero, deploy EMP on the black, silver and brown fighter jet.
# WER: 6.25%
#
# Reference 32: Air defense turret, prepare to engage blue and grey light aircraft heading three four five. Deploy anti-air artillery. Fire at will.
# Hypothesis 32:  Air defense turret, prepare to engage blue and grey light aircraft heading three four five. Deploy anti-air artillery. Fire at will.
# WER: 0.00%
#
# Reference 33: Execute precision military strike with interceptor jets on heading two one zero. Engage the silver and red cargo aircraft as the target. Carry out intercept mission immediately.
# Hypothesis 33:  Execute precision military strike with interceptor jets on Heading two one zero. Engage the silver and red cargo aircraft as the target. Carry out intercept mission immediately.
# WER: 3.70%
#
# Reference 34: Deploy anti-air artillery to intercept the silver and purple missile heading zero eight five.
# Hypothesis 34:  Deploy anti-air artillery to intercept the silver and purple missile heading zero eight five
# WER: 7.14%
#
# Reference 35: Control here, we have a grey fighter plane in our airspace. Deploy the interceptor jets immediately on a heading of three three five. Engage and neutralize the target swiftly. Over.
# Hypothesis 35:  Control here. We have a grey fighter plane in our airspace. Deploy the interceptor jets immediately on a heading of three-three-five. Engage and neutralise the target swiftly. Over.
# WER: 20.00%
#
# Reference 36: Turret Bravo, engage target, silver, blue, and brown helicopter at heading zero niner zero, deploy machine gun. Turret Charlie, standby for support.
# Hypothesis 36:  Turret Bravo, engage target Silver, Blue and Brown Helicopter at heading zero-niner-zero. Deploy machine gun. Turret Charlie, stand by for support.
# WER: 50.00%
#
# Reference 37: Engage the blue, orange, and brown drone with the machine gun, heading three two zero.
# Hypothesis 37:  Engage the Blue, Orange and Brown drone with the machine gun. Heading three two zero.
# WER: 33.33%
#
# Reference 38: Turret Bravo, deploy electromagnetic pulse on target orange and brown fighter plane heading three two zero.
# Hypothesis 38:  Turret Bravo, deploy electromagnetic pulse on target orange and brown fighter plane. Heading three-two-zero.
# WER: 31.25%
#
# Reference 39: Control tower to turrets, deploy electromagnetic pulse on heading two one zero. Target is orange, silver, and yellow commercial aircraft. Engage now.
# Hypothesis 39:  Control tower to Tarit, deploy electromagnetic pulse on heading two one zero. Target is orange, silver and yellow commercial aircraft. Engage now.
# WER: 9.09%
#
# Reference 40: Turret Charlie, engage the white and grey camouflage light aircraft at heading one niner five with anti-air artillery.
# Hypothesis 40:  Target Charlie, engage the white and grey camouflage light aircraft at heading one-niner-five with anti-air artillery.
# WER: 22.22%
#
# Reference 41: Turret Bravo, engage black cargo aircraft with interceptor jets heading three one zero.
# Hypothesis 41:  Turret Bravo, engage black cargo aircraft with interceptor jets heading three one zero.
# WER: 0.00%
#
# Reference 42: Engage target, blue and grey camouflage cargo aircraft, at heading one two five, deploy surface-to-air missiles.
# Hypothesis 42:  Engage target blue and grey camouflage cargo aircraft at heading one two five. Deploy surface to air missiles.
# WER: 43.75%
#
# Reference 43: Deploy surface-to-air missiles. Target the red missile at heading one seven zero. Engage and eliminate.
# Hypothesis 43:  Deploy surface to air missile. Target the red missile at heading one seven zero. Engage and eliminate.
# WER: 26.67%
#
# Reference 44: Turret Bravo, engage brown helicopter at heading three two zero with anti-air artillery.
# Hypothesis 44:  Turret Bravo engage Brown helicopter at heading three two zero with anti-air artillery.
# WER: 15.38%
#
# Reference 45: Control to air defense turrets, adjust heading to three six zero, deploy EMP tool on white and grey light aircraft. Stand by for confirmation of hit. Over.
# Hypothesis 45:  Control to air defense turrets. Adjust heading to three is six zero. Deploy EMP tool on white and gray light aircraft. Stand by for confirmation of hit. Uber.
# WER: 25.93%
#
# Reference 46: Deploy drone catcher, heading two one zero, engage grey, brown, and black drone.
# Hypothesis 46:  Deploy drone catcher heading two one zero. Engage grey, brown and black drone.
# WER: 30.77%
#
# Reference 47: Deploy surface-to-air missiles, target blue and yellow cargo aircraft, heading zero seven zero.
# Hypothesis 47:  Deploy surface to air missiles, target blue and yellow cargo aircraft heading zero seven zero.
# WER: 30.77%
#
# Reference 48: Turret Alpha, track green and grey light aircraft heading two five zero, prepare to deploy surface-to-air missiles. Turret Bravo, standby for further instructions.
# Hypothesis 48:  Turret Alpha, track green and grey light aircraft heading two five zero. Prepare to deploy surface to air missiles. Turret Bravo. Stand by for further instructions.
# WER: 34.78%
#
# Reference 49: Turrets, engage target, orange and brown drone at heading zero three zero, deploy drone catcher.
# Hypothesis 49:  Turrets, engage target. Orange and brown drone. At heading zero three zero, deploy drone catcher.
# WER: 26.67%
#
# Reference 50: Control here. Deploy machine gun. Target blue missile. Heading two zero five. Execute.
# Hypothesis 50:  Control here. Deploy machine gun. Target blue missile heading to zero five. Execute.
# WER: 23.08%
#
# Reference 51: Engage target, blue and orange drone, with electromagnetic pulse. Heading two one zero.
# Hypothesis 51:  Engage target blue and orange drone with electromagnetic pulse. Heading two one zero.
# WER: 15.38%
#
# Reference 52: Control to all turrets, we have a silver helicopter in our airspace at heading one four zero. Deploy EMP to take down the target. Over.
# Hypothesis 52:  Control to all turrets, we have a silver helicopter in our airspace at heading one four zero. Deploy EMP to take down the target. Over.
# WER: 0.00%
#
# Reference 53: Control to all turrets, prepare to engage target, a brown camouflage fighter plane, heading two niner five. Deploy surface-to-air missiles, maintain readiness, over.
# Hypothesis 53:  Control to all turrets. Prepare to engage target. A brown camouflage fighter plane heading two-niner-five. Deploy surface-to-air missiles. Maintain readiness. Over.
# WER: 52.17%
#
# Reference 54: Control here. Deploy EMP tool on heading two five zero, targeting the grey drone.
# Hypothesis 54:  Deploy EMP tool on heading two five zero, targeting the grey drone.
# WER: 14.29%
#
# Reference 55: Turret Charlie, deploy electromagnetic pulse on white, blue, and yellow light aircraft at heading one three five.
# Hypothesis 55:  Charlie deploy electromagnetic pulse on white, blue and yellow light aircraft at heading one three five.
# WER: 17.65%
#
# Reference 56: Control here, we are deploying an EMP tool on heading two three five to neutralize the yellow and green missile. Over.
# Hypothesis 56:  Control here. We are deploying an EMP-II on heading two-three-five to neutralize the yellow and green missile. Over.
# WER: 33.33%
#
# Reference 57: Engage target at heading two six zero, silver, green, and grey light aircraft. Deploy anti-air artillery. Protect the airspace.
# Hypothesis 57:  Engage target at heading two six zero silver, green and grey light aircraft. Deploy anti-air artillery. Protect the airspace.
# WER: 10.53%
#
# Reference 58: Deploy anti-air artillery, heading zero four zero, engage grey helicopter.
# Hypothesis 58:  Deploy anti-air artillery heading zero four zero engage grey helicopter.
# WER: 20.00%
#
# Reference 59: Engage target, black and brown light aircraft, heading one zero five, deploy anti-air artillery.
# Hypothesis 59:  Engage target black and brown light aircraft heading one zero five. Deploy anti-air artillery.
# WER: 28.57%
#
# Reference 60: Engage target, green camouflage helicopter at heading two zero five, deploy EMP.
# Hypothesis 60:  Engage target green camouflage helicopter at heading two zero five. Deploy EMP.
# WER: 25.00%
#
# Reference 61: Turret Bravo, deploy anti-air artillery on a grey, yellow, and brown fighter jet heading zero eight zero.
# Hypothesis 61:  Torrid Bravo, deploy anti-air artillery on a grey, yellow and brown fighter jet heading zero eight zero.
# WER: 11.76%
#
# Reference 62: Engage hostile target, green light aircraft, heading zero four five, deploy anti-air artillery.
# Hypothesis 62:  Engage hostile target, green light aircraft heading zero for five. Deploy anti-air artillery.
# WER: 30.77%
#
# Reference 63: Control to air defense turrets, we have a grey, silver, and purple fighter plane at heading one two zero. Deploy the anti-air artillery to engage the target. Over.
# Hypothesis 63:  Control to air defense turrets, we have a grey, silver and purple fighter plane heading one, two, zero. Deploy the anti-air artillery to engage the target. Over.
# WER: 14.29%
#
# Reference 64: Turrets, engage hostile target at heading two seven zero, orange missile, deploy machine gun, repeat, engage at heading two seven zero.
# Hypothesis 64:  Turrets, engage hostile target at heading two seven zero, orange missile, deploy machine gun, repeat, engage at heading two seven zero.
# WER: 0.00%
#
# Reference 65: Control to air defense turrets, deploy surface-to-air missiles heading zero four zero. Engage the brown and white cargo aircraft. Repeat, engage the brown and white cargo aircraft. Over.
# Hypothesis 65:  Control to air defense turrets, deploy surface to air missiles heading zero four zero. Engage the brown and white cargo aircraft. Repeat, engage the brown and white cargo aircraft. Over.
# WER: 10.71%
#
# Reference 66: Deploy interceptor jets to intercept the black and red fighter plane at heading three zero zero.
# Hypothesis 66:  Deploy interceptor jets to intercept the black and red fighter plane at heading three zero zero.
# WER: 0.00%
#
# Reference 67: Control tower instructs, initiate surface-to-air missiles, heading two two zero, engage yellow, brown, and orange drone.
# Hypothesis 67:  Control tower instructs initiate surface-to-air missiles. Heading two-two-zero, engage yellow, brown, and orange drones.
# WER: 43.75%
#
# Reference 68: Air defense turrets, engage target, green and black missile, heading zero five five, deploy EMP.
# Hypothesis 68:  Air defense turrets engage target green and black missile heading zero five five. Deploy EMP.
# WER: 33.33%
#
# Reference 69: Turret Delta, deploy electromagnetic pulse at heading zero seven five towards the red and yellow helicopter. Deploy now.
# Hypothesis 69:  Turret Delta, deploy electromagnetic pulse at heading zero seven five towards the red and yellow helicopter. Deploy now.
# WER: 0.00%
#
# Reference 70: Deploy machine gun to heading one three five, engage blue, red, and silver drone.
# Hypothesis 70:  Deploy machine gun to heading one three five. Engage blue, red, and silver drone.
# WER: 14.29%
#
# Reference 71: Air defense turret, new heading two two five. Engage the orange, yellow, and brown helicopter with electromagnetic pulse. Execute.
# Hypothesis 71:  Air Defense turret, new heading two two five. Engage the orange, yellow and brown helicopter with electromagnetic pulse. Execute.
# WER: 10.53%
#
# Reference 72: Turret Alpha, lock onto the silver, yellow, and red cargo aircraft, heading zero two zero. Deploy surface-to-air missiles. Engage.
# Hypothesis 72:  Turret Alpha, lock onto the Silver, Yellow and Red cargo aircraft heading zero two zero. Deploy surface to air missiles. Engage.
# WER: 36.84%
#
# Reference 73: Deploy electromagnetic pulse; engage yellow, blue, and green helicopter at heading two three zero.
# Hypothesis 73:  Deploy electromagnetic pulse. Engage yellow, blue and green helicopter at heading two three zero.
# WER: 21.43%
#
# Reference 74: Control tower to all air defense turrets, this is Commander Smith. Deploy EMP on brown, grey, and white fighter plane heading one one five. Take immediate action.
# Hypothesis 74:  Control tower to all air defense turrets. This is Commander Smith. Deploy EMP on brown, gray, and white fighter plane heading one one five. Take immediate action.
# WER: 11.11%
#
# Reference 75: Control here. Attention all air defense turrets, this is Control. We have identified a brown, black, and purple commercial aircraft in the heading of two four zero. Deploy electromagnetic pulse immediately to neutralize the threat. Over.
# Hypothesis 75:  Control here. Attention all air defense turrets. This is Control. We have identified a brown, black, and purple commercial aircraft in the heading of two four zero. Deploy electromagnetic pulse immediately to neutralize the threat. Over.
# WER: 5.56%
#
# Reference 76: Activate electromagnetic pulse, target black fighter plane, heading two six five.
# Hypothesis 76:  Activate electromagnetic pulse, target Black Fighter plane heading two six five.
# WER: 27.27%
#
# Reference 77: Control to air defense turrets, prepare to deploy electromagnetic pulse tool on heading two five zero. Target is brown camouflage fighter jet. Engage when ready. Execute.
# Hypothesis 77:  Control to air defense turret. Prepare to deploy electromagnetic pulse tool on heading two five zero. Target is brown camouflage fighter jet. Engage when ready. Execute.
# WER: 7.69%
#
# Reference 78: Deploy EMP on yellow and black missile at heading zero six five.
# Hypothesis 78:  Deploy EMP on yellow and black missile at heading zero six five.
# WER: 0.00%
#
# Reference 79: Turret Bravo, target the orange missile at heading two two zero, deploy EMP.
# Hypothesis 79:  Turret Bravo, target the orange missile at heading two two zero, deploy EMP.
# WER: 0.00%
#
# Reference 80: Control to Air Defense Turrets, deploy surface-to-air missiles, target the white helicopter heading two zero zero. Commence with caution.
# Hypothesis 80:  Control to air defence turret, deploy surface to air missiles, target the white helicopter heading two zero zero. Commence with caution.
# WER: 31.58%
#
# Reference 81: Turret Foxtrot, surface-to-air missiles, target the green missile at heading two one five. Engage.
# Hypothesis 81:  Target FOCS shot surface to air missiles. Target the green missile at heading two one five. Engage.
# WER: 57.14%
#
# Reference 82: Activate electromagnetic pulse on green, yellow, and grey helicopter at heading two eight five.
# Hypothesis 82:  Activate electromagnetic pulse on green, yellow, and grey helicopter at heading two eight five.
# WER: 0.00%
#
# Reference 83: Deploy machine gun, heading two niner zero, engage yellow fighter plane.
# Hypothesis 83:  Deploy machine gun heading two-niner-zero engage yellow fighter plane.
# WER: 36.36%
#
# Reference 84: Control to all air defense turrets, we have a white camouflage light aircraft approaching from heading two seven five. Deploy EMP immediately to neutralize the threat. Over.
# Hypothesis 84:  Control to all air defence turrets. We have a white camouflage light aircraft approaching from heading two seven five Deploy EMP immediately to neutralize the threat. Over.
# WER: 14.81%
#
# Reference 85: Engage target, orange and blue missile, with surface-to-air missiles. Heading one three five.
# Hypothesis 85:  Engage target orange and blue missile with surface to air missile heading one three five.
# WER: 53.85%
#
# Reference 86: Control calling all turrets, we have an incoming orange and white fighter jet at heading two zero zero. Deploy EMP to neutralize the target. Repeat, deploy EMP on orange and white fighter jet at two zero zero. Over.
# Hypothesis 86:  Control calling all turrets we have an incoming orange and white fighter jet at heading two zero zero Deploy emp to neutralize the target repeat deploy emp on orange and white fighter jet at two zero zero over
# WER: 21.05%
#
# Reference 87: Engage target at heading three two zero. Deploy machine gun on orange and yellow missile.
# Hypothesis 87:  Engage target at heading three two zero. Deploy machine gun on orange and yellow missile.
# WER: 0.00%
#
# Reference 88: Engage surface-to-air missiles, target grey and white commercial aircraft, heading zero four zero.
# Hypothesis 88:  Engage surface-to-air missiles. Target gray and white commercial aircraft heading zero four zero.
# WER: 30.77%
#
# Reference 89: Control tower to defense turrets, prepare to engage. Deploy surface-to-air missiles targeting blue, orange, and brown missile heading three two five.
# Hypothesis 89:  Control tower to defense turrets, prepare to engage. Deploy surface-to-air missiles targeting blue, orange, and brown missiles heading three-two-five.
# WER: 19.05%
#
# Reference 90: Deploy surface-to-air missiles to intercept grey and white drone, heading two niner zero.
# Hypothesis 90:  Deploy surface to air missiles to intercept grey and white drone heading to Niner Zero.
# WER: 53.85%
#
# Reference 91: Initiate electromagnetic pulse deployment on silver, blue, and brown cargo aircraft at heading two niner five. Target eliminated.
# Hypothesis 91:  Initiate electromagnetic pulse deployment on Silver, Blue and Brown cargo aircraft at heading two-niner-five. Target eliminated.
# WER: 33.33%
#
# Reference 92: Control commands, Deploy interceptor jets to the heading of one five five to intercept the yellow, blue, and green commercial aircraft.
# Hypothesis 92:  Control commands deploy interceptor jets to the heading of one five five to intercept the yellow blue and green commercial aircraft.
# WER: 19.05%
#
# Reference 93: Turret Alpha, surface-to-air missiles, heading two two zero, engage the silver and orange fighter jet.
# Hypothesis 93:  Tread Alpha surface-to-air missiles heading two-two-zero engage the Silver and Orange fighter jets.
# WER: 60.00%
#
# Reference 94: Control here. Prepare to engage the silver and red missile. Deploy surface-to-air missiles on heading one three zero. Standby for target lock. Repeat, standby for target lock.
# Hypothesis 94:  Control here. Prepare to engage the Silver and Red missile. Deploy surface to air missiles on heading one three zero. Stand by for target lock. Repeat. Stand by for target lock.
# WER: 37.04%
#
# Reference 95: Deploy electromagnetic pulse on orange and black missile at heading one seven zero.
# Hypothesis 95:  Deploying electromagnetic pulse on orange and black missile and heading one seven zero.
# WER: 15.38%
#
# Reference 96: Control tower to air defense turrets, deploy anti-air artillery at heading one four five, target yellow helicopter.
# Hypothesis 96:  Control tower to air defense turret. Deploy anti-air artillery at heading one four five. Target yellow helicopter.
# WER: 23.53%
#
# Reference 97: Engage target, white, purple, and black missile, at heading one seven five with anti-air artillery.
# Hypothesis 97:  engaged target white purple and black missiles at heading one seven five with anti-air artillery
# WER: 40.00%
#
# Reference 98: Control tower to all air defense turrets, deploy electromagnetic pulse on red helicopter heading two two zero.
# Hypothesis 98:  Control tower to all air duty, defense turrets. Deploy electromagnetic pulse on red helicopter heading two two zero.
# WER: 17.65%
#
# Reference 99: Turret Victor, engage yellow, blue, and red light aircraft heading one six five with EMP.
# Hypothesis 99:  Turret Victor engage yellow, blue and red light aircraft heading one six five with EMP.
# WER: 13.33%
#
# Reference 100: Activate EMP device, target black and grey missile at heading two eight zero. Standby for impact assessment.
# Hypothesis 100:  Activate EMP device, target black and grey missile at heading two eight zero. Stand by for impact assessment.
# WER: 11.76%
#
# Reference 101: Deploy interceptor jets, heading one six five, target brown fighter jet.
# Hypothesis 101:  Deploy interceptor jets heading one six five. Target brown fighter jets.
# WER: 36.36%
#
# Reference 102: Turrets, deploy surface-to-air missiles at heading one niner zero. Target is black, white, and yellow light aircraft. Engage at will.
# Hypothesis 102:  Turrets, deploy surface-to-air missiles at heading one-niner-zero. Target is black-white and yellow-light aircraft. Engage at will.
# WER: 35.00%
#
# Reference 103: Control tower to turrets, deploy electromagnetic pulse on grey and green commercial aircraft heading two eight five.
# Hypothesis 103:  Control tower to turrets deploy electromagnetic pulse on grey and green commercial aircraft heading
# WER: 23.53%
#
# Reference 104: Turret Alpha, deploy electromagnetic pulse on purple, black, and orange missile at heading zero three five. Stand by for confirmation.
# Hypothesis 104:  Turret Alpha, deploy electromagnetic pulse on purple, black and orange missile at heading zero three five. Stand by for confirmation.
# WER: 5.00%
#
# Reference 105: Control to surface-to-air turrets, we have a white and silver missile in our sights at heading one niner five. Deploy surface-to-air missiles immediately. Lock on target and fire at will. Make sure the threat is neutralized with extreme prejudice. Over.
# Hypothesis 105:  Control to surface-to-air turrets. We have a white and silver missile in our sights at heading one nine or five Deploy surface-to-air missiles immediately lock on target and fire at will Make sure the threat is neutralized with extreme prejudice over
# WER: 25.00%
#
# Reference 106: Control to surface-to-air turrets, prepare to engage an orange, white, and red commercial aircraft at heading zero one zero. Deploy surface-to-air missiles now.
# Hypothesis 106:  Control to surface to air turrets. Prepare to engage an orange, white and red commercial aircraft at heading zero one zero. Deploy surface to air missiles now.
# WER: 39.13%
#
# Reference 107: Turret Alpha, heading zero four five, engage purple, brown, and yellow cargo aircraft using anti-air artillery. Target acquired, prepare to strike.
# Hypothesis 107:  Turret Alpha heading is zero four five engage purple, brown and yellow cargo aircraft using Ant-Air artillery. Target acquired. Prepare to strike.
# WER: 33.33%
#
# Reference 108: Deploy EMP on silver missile heading three five zero.
# Hypothesis 108:  Deploy EMP on Silver missile heading three five zero.
# WER: 11.11%
#
# Reference 109: Turret Bravo, heading two two five, engage grey and black cargo aircraft with electromagnetic pulse.
# Hypothesis 109:  Turret Bravo heading two-two-five, engage grey and black cargo aircraft with electromagnetic pull.
# WER: 33.33%
#
# Reference 110: Control tower to air defense turrets, deploy interceptor jets to heading two one zero. Target is a grey, purple, and red cargo aircraft.
# Hypothesis 110:  Control tower to air defense turrets, deploy interceptor jets to heading two one zero. Target is a gray, purple and red cargo aircraft.
# WER: 8.70%
#
# Reference 111: Control tower to air defense turrets, target is white, orange, and yellow missile, deploy anti-air artillery, heading two three five.
# Hypothesis 111:  Control tower to air defense turret. Target is white, orange and yellow missile. Deploy anti-air artillery heading two three five.
# WER: 30.00%
#
# Reference 112: Turret Foxtrot, aim electromagnetic pulse at silver and white fighter plane heading one six five.
# Hypothesis 112:  Turret Foxtrot, aim electromagnetic pulse at Silver and White fighter plane heading one six five.
# WER: 13.33%
#
# Reference 113: Control speaking, deploy the machine gun turret to heading zero five zero. Engage the red, silver, and grey fighter plane. Take down the target swiftly and with precision. Over.
# Hypothesis 113:  Control speaking. Deploy the machine gun turret to heading zero five zero. Engage the red, silver and grey fighter plane. Take down the target swiftly and with precision. Over.
# WER: 10.34%
#
# Reference 114: Turret Alpha, surface-to-air missiles, target the blue and white missile at heading zero two five. Turret Bravo, standby for further instructions.
# Hypothesis 114:  Turret Alpha, surface-to-air missiles, target the blue and white missile at heading zero to five. Turret Bravo, stand by for further instructions.
# WER: 14.29%
#
# Reference 115: Air defense turret, target is black, silver, and red commercial aircraft heading three four zero. Deploy surface-to-air missiles now. Lock on and engage.
# Hypothesis 115:  Air defense turret target is black, silver and red commercial aircraft heading three four zero. Deploy surface to air missiles now. Lock on and engage.
# WER: 21.74%
#
# Reference 116: Turret Charlie, target the black and yellow fighter jet at heading three zero zero, deploy surface-to-air missiles. Fire at will.
# Hypothesis 116:  Turret Charlie, target the black and yellow fighter jet at heading three zero zero. Deploy surface to air missiles. Fighter at will.
# WER: 30.00%
#
# Reference 117: Turret Golf, heading one eight five, target grey missile, deploy electromagnetic pulse.
# Hypothesis 117:  Turret Golf, heading one eight five, the target gray missiles deploy electromagnetic poles.
# WER: 33.33%
#
# Reference 118: Activate anti-air artillery, target black and white drone at heading three zero zero. Engage immediately.
# Hypothesis 118:  Activate anti-air artillery target black and white drone at heading three zero zero. Engage immediately.
# WER: 6.67%
#
# Reference 119: Deploy machine gun to heading one five zero, engage silver, green, and yellow light aircraft.
# Hypothesis 119:  Deploy machine gun to heading one five zero. Engage silver, green, and yellow light aircraft.
# WER: 13.33%
#
# Reference 120: Control to air defense turrets, we have a target at heading one eight zero. Deploy surface-to-air missiles to engage the silver, white, and orange light aircraft. Over.
# Hypothesis 120:  Control to air defense turret, we have a target at heading one eight zero. Deploy surface to air missiles to engage the silver, white and orange light aircraft. Over.
# WER: 18.52%
#
# Reference 121: Control tower to air defense turrets, target at heading zero three five, black and white camouflage fighter plane identified. Deploy EMP immediately.
# Hypothesis 121:  Control tower to air defense storage. Target at heading zero three five. Black and white camouflage fighter plane identified. Deploy DMP immediately.
# WER: 22.73%
#
# Reference 122: Control to turrets, update heading to three six zero degrees. Deploy surface-to-air missiles on blue commercial aircraft. Take necessary precautions. Over.
# Hypothesis 122:  Control to turrets, update heading to three six zero degrees. Deploy surface to air missiles on blue commercial aircraft. Take necessary precautions. Over.
# WER: 14.29%
#
# Reference 123: Set heading to One Eight Zero. Deploy EMP on brown missile.
# Hypothesis 123:  Set heading to one eight zero deploy EMP on brown missus.
# WER: 45.45%
#
# Reference 124: Fire EMP at red, orange, and blue fighter plane at heading zero five zero.
# Hypothesis 124:  fire. EMP at red, orange and blue. Fighter plane at heading zero, five, zero.
# WER: 42.86%
#
# Reference 125: Control here. Deploy the machine gun on the orange light aircraft heading two seven zero. Engage and neutralize the target immediately.
# Hypothesis 125:  Control here. Deploy the machine gun on the orange light aircraft heading two seven zero. Engage and neutralize the target immediately.
# WER: 0.00%
#
# Reference 126: Turret Romeo, engage red, white, and grey missile at heading two one zero with anti-air artillery.
# Hypothesis 126:  Torrid Romeo engage red, white and grey missile heading two one zero with anti-air artillery.
# WER: 25.00%
#
# Reference 127: Initiate electromagnetic pulse deployment against the brown, silver, and green drone at heading three four zero. Launch now.
# Hypothesis 127:  Initiate electromagnetic pulse deployment against the brown, silver, and green drone at heading three four zero. Launch now.
# WER: 0.00%
#
# Reference 128: Control to air defense turrets, deploy anti-air artillery to heading zero two five. Engage the white and green commercial aircraft. Repeat, deploy anti-air artillery to heading zero two five, engage the white and green commercial aircraft. Over.
# Hypothesis 128:  Control to air defense turrets. Deploy anti-air artillery to heading zero two five. Engage the white and green commercial aircraft. Repeat. Deploy anti-air artillery to heading zero two five. Engage the white and green commercial aircraft. Over.
# WER: 16.22%
#
# Reference 129: Turret Alpha, surface-to-air missiles, heading two eight zero. Engage white, yellow, and orange drone. Tango down.
# Hypothesis 129:  Turret Alpha, surface to air missile heading two eight zero. Engage white, yellow and orange drones. Tango down.
# WER: 37.50%
#
# Reference 130: Deploy machine gun, heading one two zero, engage target red missile.
# Hypothesis 130:  Deploy machine gun heading one two zero. Engage target red missile.
# WER: 27.27%
#
# Reference 131: Control tower to air defense turrets, deploy surface-to-air missiles on blue, white, and purple fighter jet heading zero six five.
# Hypothesis 131:  Control tower to air defense turret. Deploy surface to air missiles on blue, white and purple fighter jet heading zero six five.
# WER: 30.00%
#
# Reference 132: Control commands air defense turrets to engage target, a yellow camouflage light aircraft, at heading zero zero five using electromagnetic pulse. Execute immediately!
# Hypothesis 132:  Control commands air defence turrets to engage target. A yellow camouflage light aircraft at heading zero zero five using electromagnetic pulse. Execute immediately.
# WER: 21.74%
#
# Reference 133: Control to turrets, heading two six zero. Deploy machine gun on grey light aircraft. Engage target. Over.
# Hypothesis 133:  Control to turrets heading two six zero. Deploy machine gun on gray light aircraft. Engage target. Over.
# WER: 11.76%
#
# Reference 134: Deploy anti-air artillery, target grey and yellow commercial aircraft, heading zero two zero.
# Hypothesis 134:  Deploy anti-air artillery. Target gray and yellow commercial aircraft heading zero to zero.
# WER: 38.46%
#
# Reference 135: Control tower to turrets, deploy surface-to-air missiles on red, orange, and purple missile at heading one four five. Launch!
# Hypothesis 135:  Control tower to turrets deploy surface to air missiles on red, orange and purple missile at heading one four five. Launch.
# WER: 31.58%
#
# Reference 136: Control tower to air defense turrets, target located at heading two three five, white, yellow, and silver fighter jet. Deploy anti-air artillery to intercept immediately.
# Hypothesis 136:  Control tower to air defense turrets. Target located at heading two three five. White, yellow and silver fighter jet. Deploy anti-air artillery to intercept immediately.
# WER: 20.00%
#
# Reference 137: Control tower to turrets, prepare to deploy electromagnetic pulse on heading zero six five towards grey drone. Stand by for further instructions.
# Hypothesis 137:  Control tower to turrets. Prepare to deploy electromagnetic pulse on heading zero six five towards gray drone. Stand by for further instructions.
# WER: 13.64%
#
# Reference 138: Engage red and yellow fighter plane at heading one one zero with anti-air artillery.
# Hypothesis 138:  Engage red and yellow fighter plane at heading one one zero with anti air artillery.
# WER: 14.29%
#
# Reference 139: Engage hostile black and grey commercial aircraft at heading three four zero, deploy anti-air artillery.
# Hypothesis 139:  Engage hostile black and grey commercial aircraft at heading three four zero. Deploy anti-air artillery.
# WER: 13.33%
#
# Reference 140: Air defense turret, deploy surface-to-air missiles towards a silver cargo aircraft at heading zero one five. Engage target.
# Hypothesis 140:  Air Defence Turret, deploy surface-to-air missiles towards the Silver Cargo aircraft at heading zero one five. Engage target.
# WER: 27.78%
#
# Reference 141: Deploy surface-to-air missiles to heading two one zero. Target orange and red missile. Lock on and fire.
# Hypothesis 141:  Deploy surface to air missiles to heading two one zero. Target orange and red missiles. Lock on and fire.
# WER: 23.53%
#
# Reference 142: Control tower to all air defense turrets, priority target spotted in our airspace. Deploy surface-to-air missiles against red and brown camouflage drone heading two eight five. Seek and destroy. Over.
# Hypothesis 142:  Control tower to all air defence turrets. Priority targets spotted in our airspace. Deploy surface-to-air missiles against red and brown camouflage drone heading two-eight-five. Seek and destroy. Over.
# WER: 23.33%
#
# Reference 143: Control tower to turrets, deploy EMP on red and white commercial aircraft heading three one zero.
# Hypothesis 143:  Control tower to turret, deploy EMP on red and white commercial aircraft heading three one zero.
# WER: 6.25%
#
# Reference 144: Turret Alpha, deploy EMP on brown and white missile heading one seven five.
# Hypothesis 144:  Torret Alpha, deploy EMP on brown and white, missile heading one seven five.
# WER: 15.38%
#
# Reference 145: Control Tower to Air Defense Turrets, deploy electromagnetic pulse on red and brown missile at heading zero six zero.
# Hypothesis 145:  Control tower to air defense turrets. Deploy electromagnetic pulse on red and brown missile at heading zero six zero.
# WER: 26.32%
#
# Reference 146: Turret Bravo, deploy anti-air artillery towards three two zero. Engage brown, grey, and black cargo aircraft. Repeat, engage brown, grey, and black cargo aircraft with anti-air artillery at three two zero.
# Hypothesis 146:  Torret Bravo, deploy anti-air artillery towards three two zero. Engage brown, gray, and black cargo aircraft. Repeat, engage brown, gray, and black cargo aircraft with anti-air artillery at three two zero.
# WER: 9.68%
#
# Reference 147: Air defense turret, prepare to engage. Target is a brown, yellow, and white fighter plane at heading zero four zero. Deploy anti-air artillery. Engage now.
# Hypothesis 147:  Air Defence Turret, prepare to engage. Target is a brown, yellow and white fighter plane at heading zero four zero. Deploy anti-air artillery. Engage now.
# WER: 12.00%
#
# Reference 148: Control tower to anti-air artillery, engage purple, yellow, and brown drone heading three zero zero.
# Hypothesis 148:  Control tower to Antier Artillery. Engage purple, yellow and brown drone heading three zero zero.
# WER: 26.67%
#
# Reference 149: Prepare to engage target, green cargo aircraft, heading two two five. Deploying surface-to-air missiles. Engage when ready.
# Hypothesis 149:  Prepare to engage target. Green cargo aircraft heading two two five. Deploying surface to air missile. Engage when ready.
# WER: 41.18%
#
# Reference 150: Control to turrets, deploy EMP. Target is a white helicopter heading two two zero. Engage and neutralize the threat immediately. Over.
# Hypothesis 150:  Control to turrets deploy EMP. Target is a white helicopter heading two two zero. Engage and neutralize the threat immediately. Over.
# WER: 4.76%
#
# Reference 151: Control to air defense turrets, we have a target consisting of a brown, purple, and yellow drone at heading three three five. Deploy surface-to-air missiles immediately. Engage and neutralize the threat. Over.
# Hypothesis 151:  With Control to Air Defence Torrets, we have a target consisting of a brown, purple and yellow drone at heading three three five. Deploy surface to air missiles immediately. Engage and neutralise the threat. Over.
# WER: 28.12%
#
# Reference 152: Turret Alpha, lock onto the purple, blue, and silver light aircraft at heading zero zero five. Engage target with anti-air artillery.
# Hypothesis 152:  Turret Alpha, lock on to the purple, blue and silver light aircraft at heading zero zero five. Engage target with anti-air artillery.
# WER: 14.29%
#
# Reference 153: Turret Bravo, deploy machine gun. Target is a purple, grey, and silver missile at heading zero one five. Engage with precision fire.
# Hypothesis 153:  Turret Bravo, deploy machine gun. Target is a purple, grey and silver missile at heading zero one five. Engage with precision fire.
# WER: 4.55%
#
# Reference 154: Control tower to air defense turrets, deploy electromagnetic pulse on yellow, red, and grey commercial aircraft heading three zero five.
# Hypothesis 154:  Control tower to air defense turrets deploy electromagnetic pulse on yellow, red and gray commercial aircraft heading three zero five.
# WER: 15.00%
#
# Reference 155: Turret Mike, altitude thirty five degrees, engage using machine gun, target the blue fighter jet at heading three two five.
# Hypothesis 155:  Starrett Mike, altitude is thirty-five degrees, engage using machine gun. Target the blue fighter jet at heading three-two-five.
# WER: 40.00%
#
# Reference 156: Control to all turrets, deploy machine gun, heading zero five five, engage the yellow light aircraft. Repeat, deploy the machine gun, heading zero five five, engage the yellow light aircraft. Over.
# Hypothesis 156:  Control to all turrets, deploy machine gun heading zero five five, engage the yellow light aircraft. Repeat, deploy the machine gun heading zero five five, engage the yellow light aircraft. Over.
# WER: 6.45%
#
# Reference 157: Target the blue, brown, and silver helicopter heading two three five. Deploy EMP.
# Hypothesis 157:  Target the blue, brown and silver helicopter heading two-three-five. Deploy EMP.
# WER: 30.77%
#
# Reference 158: Rotate turret to heading zero seven five. Engage target, red camouflage light aircraft, with surface-to-air missiles. Execute fire sequence.
# Hypothesis 158:  Rotate turret to heading zero seven five. Engage target. Red camouflage light. Ease aircraft with surface to air missiles. Execute fire sequence.
# WER: 42.11%
#
# Reference 159: Turret Bravo, engage the silver, orange, and red fighter plane at heading zero six zero with anti-air artillery. Turret Bravo, firing now.
# Hypothesis 159:  Turret Bravo engage the silver, orange and red fighter plane at heading zero six zero with anti-air artillery. Turret Bravo firing now.
# WER: 13.64%
#
# Reference 160: Turret Bravo, deploy interceptor jets to intercept the silver cargo aircraft at heading zero eight five.
# Hypothesis 160:  Turret Bravo, deploy interceptor jets to intercept a silver cargo aircraft at heading zero eight five.
# WER: 6.25%
#
# Reference 161: Control to all voice-controlled air defense turrets, we have a white fighter jet approaching at a heading of zero zero five. Deploy the interceptor jets to intercept the target. Repeat, deploy the interceptor jets to intercept the target. Over.
# Hypothesis 161:  Control to all voice controlled air defense turret. We have a white fighter jet approaching at a heading of zero zero five Deploy the interceptor jets to intercept the target repeat deploy the interceptor jets to intercept the target over
# WER: 23.08%
#
# Reference 162: Control here. Prepare to deploy electromagnetic pulse at heading two zero five. Target is a black, purple, and white cargo aircraft. Engage at will. Over.
# Hypothesis 162:  Control here. Prepare to deploy electromagnetic pulse at heading two zero five. Pocket is a black, purple and white cargo aircraft. Engage at will. Over.
# WER: 8.00%
#
# Reference 163: Control tower to turrets, prepare to engage, deploy electromagnetic pulse on white and black light aircraft heading one zero zero.
# Hypothesis 163:  Control tower to turrets, prepare to engage. Deploy electromagnetic poles on white and black light aircraft heading one zero zero.
# WER: 15.00%
#
# Reference 164: Engage electromagnetic pulse on blue, orange, and silver fighter jet heading two six zero.
# Hypothesis 164:  Engage electromagnetic poles on Blue, Orange and Silver fighter jets heading to six zero.
# WER: 42.86%
#
# Reference 165: Control to turrets, we have blue, purple, and red commercial aircraft at heading one two five. Deploy EMP tool immediately.
# Hypothesis 165:  Control to turrets, we have blue, purple and red commercial aircraft at heading one-two-five. Deploy EMP tool immediately.
# WER: 20.00%
#
# Reference 166: Engage, brown, grey, and black drone with anti-air artillery at heading two niner zero.
# Hypothesis 166:  Engage brown, grey and black drone with anti-air artillery at heading two-nine-o-zero.
# WER: 35.71%
#
# Reference 167: Control to air defense turrets, we have a white and orange commercial aircraft at heading two eight five. Deploy interceptor jets to intercept the target. Over.
# Hypothesis 167:  Control to air defense turrets. We have a white and orange commercial aircraft at heading two eight five. Deploy interceptor jets to intercept the target. Over.
# WER: 7.69%
#
# Reference 168: Control here, deploy electromagnetic pulse on orange, black, and purple light aircraft heading zero three five. Over.
# Hypothesis 168:  Control here, deploy electromagnetic pulse on orange, black and purple light aircraft heading zero three five. Over.
# WER: 5.88%
#
# Reference 169: Deploy EMP on brown and purple cargo aircraft heading two niner zero.
# Hypothesis 169:  Deploy EMP on brown and purple cargo aircraft heading two-niner-zero.
# WER: 25.00%
#
# Reference 170: Tower to turrets, deploy surface-to-air missiles. Heading two six zero. Target is grey, yellow, and silver fighter plane.
# Hypothesis 170:  tower to turrets, deploy surface to air missiles. Heading two six zero, target is gray, yellow and silver fighter plane.
# WER: 44.44%
#
# Reference 171: Control tower to turrets, prepare to deploy electromagnetic pulse. Target is a red commercial aircraft on heading one three five. Take action immediately.
# Hypothesis 171:  Control tower to Taurus. Prepare to deploy electromagnetic pulse. Target is a red commercial aircraft on heading one three five. Take action immediately.
# WER: 8.70%
#
# Reference 172: Engage target, white and orange helicopter, heading one niner five, with machine gun.
# Hypothesis 172:  Engage target, white and orange helicopter heading one-niner-five with machine gun.
# WER: 30.77%
#
# Reference 173: Control to air defense turrets, focus your attention to heading two two five. Prepare to deploy EMP tool against the brown and white commercial aircraft. Engage and neutralize the target swiftly. Over.
# Hypothesis 173:  Control to air defense turrets. Focus your attention to heading two two five. Prepare to deploy EMP tool against the brown and white commercial aircraft. Engage and neutralize the target swiftly. Over.
# WER: 6.25%
#
# Reference 174: Control here. Prepare to engage brown fighter jet at heading two four five using machine gun. Fire at will. Over.
# Hypothesis 174:  Control here. Prepare to engage Brown Fighter Jet at heading two-four-five using machine gun. Fire at will. Over.
# WER: 30.00%
#
# Reference 175: Tango, deploy electromagnetic pulse at heading one four zero, targeting blue and green fighter jet.
# Hypothesis 175:  Tango deploy electromagnetic pulse at heading one four zero targeting blue and green fighter jet.
# WER: 13.33%
